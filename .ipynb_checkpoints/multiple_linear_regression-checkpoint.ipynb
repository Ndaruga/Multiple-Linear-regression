# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import math
import seaborn as sn
import matplotlib.pyplot as plt

# %%
korea_df = pd.read_excel('korea_data.xlsx')
korea_df.shape
# Out:
# (49, 11)

# %%
korea_df.columns
# Out:
# Index(['Year', 'GDP growth (annual %)', 'Gross capital formation (% of GDP)',
#        'Population growth (annual %)', 'Birth rate, crude (per 1,000 people)',
#        'Broad money growth (annual %)',
#        'Final consumption expenditure (annual % growth)',
#        'General government final consumption expenditure (annual % growth)',
#        'Gross capital formation (annual % growth)',
#        'Households and NPISHs Final consumption expenditure (annual % growth)',
#        'Unemployment, total (% of total labor force) (national estimate)'],
#       dtype='object')

# %%
korea_df.head(2)
# Out:
#    Year  GDP growth (annual %)  Gross capital formation (% of GDP)  \
# 0  1969              14.541235                           29.943577
# 1  1970               9.997407                           26.338200
#
#    Population growth (annual %) Birth rate, crude (per 1,000 people)  \
# 0                      2.263434                               30.663
# 1                      2.184174                                 31.2
#
#    Broad money growth (annual %)  \
# 0                      60.984733
# 1                      27.422864
#
#    Final consumption expenditure (annual % growth)  \
# 0                                        10.693249
# 1                                        10.161539
#
#    General government final consumption expenditure (annual % growth)  \
# 0                                          10.640799
# 1                                           7.279573
#
#    Gross capital formation (annual % growth)  \
# 0                                  29.908118
# ...

# %% [markdown]
# The file contains some empty values which appear as ..
# We need to replace all the .. values with nan

# %%
korea_df = korea_df.replace('..', 'nan')

# %%
korea_df.index = korea_df['Year']

# %%
korea_df = korea_df.drop('Year', axis = 1)
korea_df.head(3)
# Out:
#       GDP growth (annual %)  Gross capital formation (% of GDP)  \
# Year
# 1969              14.541235                           29.943577
# 1970               9.997407                           26.338200
# 1971              10.454693                           25.558501
#
#       Population growth (annual %) Birth rate, crude (per 1,000 people)  \
# Year
# 1969                      2.263434                               30.663
# 1970                      2.184174                                 31.2
# 1971                      1.971324                                 31.2
#
#       Broad money growth (annual %)  \
# Year
# 1969                      60.984733
# 1970                      27.422864
# 1971                      20.844481
#
#       Final consumption expenditure (annual % growth)  \
# Year
# 1969                                        10.693249
# 1970                                        10.161539
# 1971                                         9.330434
#
# ...

# %% [markdown]
# change the datatype of the whole dataset to a float

# %% [markdown]
# korea_df = korea_df.astype(float)

# %%
korea_df = korea_df.astype(float)

# %%
korea_df = korea_df.loc['1969':'2016']
korea_df.tail(3)
# Out:
#       GDP growth (annual %)  Gross capital formation (% of GDP)  \
# Year
# 2014               3.341448                           29.276910
# 2015               2.790236                           28.918112
# 2016               2.929305                           29.252387
#
#       Population growth (annual %)  Birth rate, crude (per 1,000 people)  \
# Year
# 2014                      0.628150                                   8.6
# 2015                      0.527288                                   8.6
# 2016                      0.451318                                   7.9
#
#       Broad money growth (annual %)  \
# Year
# 2014                       8.144493
# 2015                       8.190748
# 2016                       7.123156
#
#       Final consumption expenditure (annual % growth)  \
# Year
# 2014                                         2.042800
# 2015                                         2.385188
# 2016                                         2.981150
#
# ...

# %%
# Renaming the column names to smaller values using key value pairs
# column_names = {'Unemployment, total (% of total labor force) (national estimate)':'unemployment',
#                 'GDP growth (annual %)': 'gdp_growth',
#                 'Gross capital formation (% of GDP)':'gross_capital_formation',
#                 'Population growth (annual %)':'pop_growth', 
#                 'Birth rate, crude (per 1,000 people)':'birth_rate',
#                 'Broad money growth (annual %)':'broad_money_growth',                
#                 'Final consumption expenditure (% of GDP)':'final_consum_gdp',
#                 'Final consumption expenditure (annual % growth)':'final_consum_growth',
#                 'General government final consumption expenditure (annual % growth)':'gov_final_consum_growth',
#                 'Gross capital formation (annual % growth)':'gross_cap_form_growth',
#                 'Households and NPISHs Final consumption expenditure (annual % growth)':'hh_consum_growth'}

# #rename columns
# korea_df = korea_df.rename(columns = column_names)
# print('='*100)
# display(korea_df.isnull().any())

print('='*100)
display(korea_df.head())
# Out:
# ...
#       GDP growth (annual %)  Gross capital formation (% of GDP)  \
# Year
# 1969              14.541235                           29.943577
# 1970               9.997407                           26.338200
# 1971              10.454693                           25.558501
# 1972               7.150715                           21.404761
# 1973              14.827554                           25.872858
#
#       Population growth (annual %)  Birth rate, crude (per 1,000 people)  \
# Year
# 1969                      2.263434                                30.663
# 1970                      2.184174                                31.200
# 1971                      1.971324                                31.200
# 1972                      1.875999                                28.400
# 1973                      1.768293                                28.300
#
#       Broad money growth (annual %)  \
# Year
# 1969                      60.984733
# 1970                      27.422864
# ...

# %%
correlation = korea_df.corr()
display(correlation)

#plot the correlation on a heatmap
heatmp = sn.heatmap(correlation, xticklabels = correlation.columns, yticklabels = correlation.columns, cmap = 'RdBu')
display(heatmp)
# Out:
#                                                     GDP growth (annual %)  \
# GDP growth (annual %)                                            1.000000
# Gross capital formation (% of GDP)                               0.086712
# Population growth (annual %)                                     0.567216
# Birth rate, crude (per 1,000 people)                             0.553225
# Broad money growth (annual %)                                    0.335249
# Final consumption expenditure (annual % growth)                  0.855835
# General government final consumption expenditur...               0.098183
# Gross capital formation (annual % growth)                        0.825496
# Households and NPISHs Final consumption expendi...               0.868848
# Unemployment, total (% of total labor force) (n...              -0.160783
#
#                                                     Gross capital formation (% of GDP)  \
# ...

# %%
pd.plotting.scatter_matrix(korea_df, alpha = 1, figsize = (60,60))
plt.show()

# %% [markdown]
# we need to determine how each variable in the data frame is contributing to the standard error.

# %% [markdown]
# <!-- For this we use the variance_inflation_factor

# %%
from scipy import stats
import statsmodels.api as sm
from statsmodels.stats import diagnostic as diag
from statsmodels.stats.outliers_influence import variance_inflation_factor

korea_df_before = korea_df

def calc_vif(x):
    vif = pd.DataFrame()
    vif["variables"] = x.columns
    vif["VIF"] = [variance_inflation_factor(x.values, i) for i in range(x.shape[1])]
    return(vif)

# %%
display('-'*100)
print("Vif values before")
x = korea_df_before.iloc[:, :]
calc_vif(x)
# korea_df_before.info()
# Out:
# '----------------------------------------------------------------------------------------------------'
# Vif values before
#                                            variables          VIF
# 0                              GDP growth (annual %)    37.913516
# 1                 Gross capital formation (% of GDP)    16.716693
# 2                       Population growth (annual %)   135.902059
# 3               Birth rate, crude (per 1,000 people)   178.598539
# 4                      Broad money growth (annual %)     4.795711
# 5    Final consumption expenditure (annual % growth)  5690.345801
# 6  General government final consumption expenditu...   121.786911
# 7          Gross capital formation (annual % growth)     5.304715
# 8  Households and NPISHs Final consumption expend...  4265.490934
# 9  Unemployment, total (% of total labor force) (...    18.176169

# %%
display('-'*100)
print("Vif values after")
# drop columns with more than 5
korea_df_after = korea_df.drop(['GDP growth (annual %)','Gross capital formation (% of GDP)','Population growth (annual %)','Final consumption expenditure (annual % growth)','Households and NPISHs Final consumption expenditure (annual % growth)','Birth rate, crude (per 1,000 people)'], axis =1)
# korea_df_after.head(3)
x = korea_df_after.iloc[:, :]
calc_vif(x)
# Out:
# '----------------------------------------------------------------------------------------------------'
# Vif values after
#                                            variables       VIF
# 0                      Broad money growth (annual %)  3.929475
# 1  General government final consumption expenditu...  4.652596
# 2          Gross capital formation (annual % growth)  1.551089
# 3  Unemployment, total (% of total labor force) (...  5.360218

# %%
print("Heat map")
corr = korea_df_after.corr()
hmp = sn.heatmap(corr, xticklabels = corr.columns, yticklabels = corr.columns, cmap = 'RdBu' )
display(hmp)
# Out:
# Heat map
# <AxesSubplot:>

# %%
pd.plotting.scatter_matrix(korea_df_after, alpha = 1, figsize = (60,60))
plt.show()

# %%
# check for outliers using zscore and standard deviations
# check for the description of the dataset
desc_korea_df = korea_df.describe()
desc_korea_df
# Out:
#        GDP growth (annual %)  Gross capital formation (% of GDP)  \
# count              48.000000                           48.000000
# mean                7.280315                           32.433236
# std                 4.209306                            4.136932
# min                -5.471219                           21.404761
# 25%                 4.374899                           29.776910
# 50%                 7.513471                           32.335229
# 75%                10.376191                           34.474874
# max                14.827554                           41.374062
#
#        Population growth (annual %)  Birth rate, crude (per 1,000 people)  \
# count                     48.000000                             48.000000
# mean                       1.058072                             16.340896
# std                        0.514039                              6.814683
# min                        0.211998                              7.900000
# ...

# %%
# adding a positive and negative stsndard deviation of +3 and -3 respectively
desc_korea_df.loc['+3_std'] = desc_korea_df.loc['mean'] + (desc_korea_df.loc['std'] * 3)
desc_korea_df.loc['-3_std'] = desc_korea_df.loc['mean'] - (desc_korea_df.loc['std'] * 3)
desc_korea_df
# Out:
#         GDP growth (annual %)  Gross capital formation (% of GDP)  \
# count               48.000000                           48.000000
# mean                 7.280315                           32.433236
# std                  4.209306                            4.136932
# min                 -5.471219                           21.404761
# 25%                  4.374899                           29.776910
# 50%                  7.513471                           32.335229
# 75%                 10.376191                           34.474874
# max                 14.827554                           41.374062
# +3_std              19.908232                           44.844034
# -3_std              -5.347602                           20.022439
#
#         Population growth (annual %)  Birth rate, crude (per 1,000 people)  \
# count                      48.000000                             48.000000
# mean                        1.058072                             16.340896
# ...

# %%
# to remove the outliers that cause very high standard deviation
remove_outliers_df = korea_df[(np.abs(stats.zscore(korea_df))<3).all(axis = 1)]
korea_df.index.difference(remove_outliers_df.index)
# Out:
# Int64Index([1998, 2001], dtype='int64', name='Year')

# %% [markdown]
# From the above output we can tell that 2 rows are outliers i.e, 1998, 2001

# %% [markdown]
# Building the model

# %%
X = korea_df.drop('GDP growth (annual %)', axis = 1)
Y = korea_df[['GDP growth (annual %)']]
X
# Out:
#       Gross capital formation (% of GDP)  Population growth (annual %)  \
# Year
# 1969                           29.943577                      2.263434
# 1970                           26.338200                      2.184174
# 1971                           25.558501                      1.971324
# 1972                           21.404761                      1.875999
# 1973                           25.872858                      1.768293
# 1974                           32.533408                      1.712705
# 1975                           28.959267                      1.682000
# 1976                           27.555990                      1.596559
# 1977                           30.630713                      1.559039
# 1978                           34.532492                      1.519197
# 1979                           38.132587                      1.516875
# 1980                           34.455668                      1.558463
# ...

# %%
# spliiting the data into train and test
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size = 0.2, random_state = 0)

# create an instance of our model
regrr = LinearRegression()

# next we fit our data into the model
regrr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
# make a prediction
y_pred = regrr.predict(x_test)
y_pred
# Out:
# array([[-9.89769596],
#        [14.48575355],
#        [10.67024052],
#        [10.8799537 ],
#        [ 6.73463394],
#        [ 4.59402514],
#        [ 1.92474029],
#        [ 0.78319098],
#        [12.89051175],
#        [ 9.96779678]])

# %%
# model evaluation
from sklearn.metrics import accuracy_score

acc = accuracy_score(y_test, y_pred)
acc
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [25], in <cell line: 4>()
#       1 # model evaluation
#       2 from sklearn.metrics import accuracy_score
# ----> 4 acc = accuracy_score(y_test, y_pred)
#       5 acc
#
# File ~\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:211, in accuracy_score(y_true, y_pred, normalize, sample_weight)
#     145 """Accuracy classification score.
#     146
#     147 In multilabel classification, this function computes subset accuracy:
#    (...)
#     207 0.5
#     208 """
#     210 # Compute accuracy for each possible representation
# --> 211 y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     212 check_consistent_length(y_true, y_pred, sample_weight)
#     213 if y_type.startswith("multilabel"):
#
# File ~\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:104, in _check_targets(y_true, y_pred)
# ...
